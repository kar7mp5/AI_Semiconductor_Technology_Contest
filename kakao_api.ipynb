# %%
import requests
import pandas as pd
import numpy as np
import folium
from folium.plugins import MiniMap

# %%
from dotenv import load_dotenv
import os

load_dotenv()
KAKAO_API = os.getenv('KAKAO_REST_API')

# %%
##카카오 API
## region에는 '성산일출봉 전기충전소' 검색명이 들어갈 것임
## page_num은 1~3이 입력될 건데, 한 페이지 당 검색목록이 최대 15개임.
## 만약 page_num이 4이상이 되면 3페이지랑 같은 15개의 결과 값을 가져옴. 그래서 1~3만 쓰는 것임
## 입력 예시 -->> headers = {"Authorization": "KakaoAK f221u3894o198123r9"}
## ['meta']['total_count']은 내가 '성산일출봉 전기충전소'를 검색했을 때, 나오는 총 결과 값. 
## ['meta']['total_count']이 45보다 크면 45개만 가져오게 됨


def elec_location(region,page_num):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json'
    params = {'query': region,'page': page_num}
    headers = {"Authorization": f"KakaoAK {KAKAO_API}"}

    print(requests.get(url, params=params, headers=headers).json())
    places = requests.get(url, params=params, headers=headers).json()['documents']
    total = requests.get(url, params=params, headers=headers).json()['meta']['total_count']
    if total > 45:
        print(total,'개 중 45개 데이터밖에 가져오지 못했습니다!')
    else :
        print('모든 데이터를 가져왔습니다!')
    return places

# %%
## 이 함수는 위 함수 결과 값(1 ~ 45개) 하나하나 분리해서 저장할 것임
## 1번 결과 값 안에는 1번 충전소 이름, 위도, 경도, 전화번호, 도로명 주소 등이 있는데 각각 배열에 저장
## 우리는 충전소 ID, 충전소 이름, 위도, 경도, 도로명주소, 사이트주소를 저장할 것임

def elec_info(places):
    X = []
    Y = []
    stores = []
    road_address = []
    place_url = []
    ID = []
    for place in places:
        X.append(float(place['x']))
        Y.append(float(place['y']))
        stores.append(place['place_name'])
        road_address.append(place['road_address_name'])
        place_url.append(place['place_url'])
        ID.append(place['id'])

    ar = np.array([ID,stores, X, Y, road_address,place_url]).T
    df = pd.DataFrame(ar, columns = ['ID','stores', 'X', 'Y','road_address','place_url'])
    return df

# %%
## 여러개으 키워드를 검색할 때 사용할 함수임
## location_name에는 ['성산일출봉 전기충전소, '한림공원 전기충전소', ... ,'모슬포 전기충전소']처럼 배열이 입력

def keywords(location_name):
    df = None
    for loca in location:
        for page in range(1,4):
            local_name = elec_location(loca, page)
            local_elec_info = elec_info(local_name)

            if df is None:
                df = local_elec_info
            elif local_elec_info is None:
                continue
            else:
                df = pd.concat([df, local_elec_info],join='outer', ignore_index = True)
    return df

# %%
##지도로 보여주기

def make_map(dfs):
    # 지도 생성하기
    m = folium.Map(location=[33.4935,126.6266],   # 기준좌표: 제주어딘가로 내가 대충 설정
                   zoom_start=12)

    # 미니맵 추가하기
    minimap = MiniMap() 
    m.add_child(minimap)

    # 마커 추가하기
    for i in range(len(dfs)):
        folium.Marker([df['Y'][i],df['X'][i]],
                  tooltip=dfs['stores'][i],
                  popup=dfs['place_url'][i],
                  ).add_to(m)
    return m

# %%
## 여기 두 개 키워드처럼 가까운 거리에 있는 키워드를 입력하면 
## 중복해서 전기충전소를 검색할 가능성이 아주 놓기 때문에
## drop_duplicates를 해주고 인덱스 리셋을 해준다

location = ['성산일출봉 전기충전소', '광치기해수욕장 전기충전소']
df = keywords(location)
df = df.drop_duplicates(['ID'])
df = df.reset_index()

make_map(df)
# Out:
# {'documents': [{'address_name': '제주특별자치도 서귀포시 성산읍 성산리 114-3', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '2126955165', 'phone': '', 'place_name': '성산일출봉 전기차충전소', 'place_url': 'http://place.map.kakao.com/2126955165', 'road_address_name': '제주특별자치도 서귀포시 성산읍 일출로 284-6', 'x': '126.93554153441724', 'y': '33.46143067760281'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 141', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '359173519', 'phone': '062-941-9360', 'place_name': '돌하르방뚝배기식당 전기차충전소', 'place_url': 'http://place.map.kakao.com/359173519', 'road_address_name': '제주특별자치도 서귀포시 성산읍 일출로 264', 'x': '126.9339088143998', 'y': '33.461200809073716'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 293-1', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '1150578399', 'phone': '1533-5421', 'place_name': '제주 스타펜션민박 전기차충전소', 'place_url': 'http://place.map.kakao.com/1150578399', 'road_address_name': '제주특별자치도 서귀포시 성산읍 성산중앙로64번길 5-1', 'x': '126.93557249234316', 'y': '33.46465935757893'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 177-3', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '1054258278', 'phone': '1588-5339', 'place_name': '휴안스테이호텔 전기차충전소', 'place_url': 'http://place.map.kakao.com/1054258278', 'road_address_name': '제주특별자치도 서귀포시 성산읍 성산중앙로40번길 4', 'x': '126.93367179272992', 'y': '33.46310037403955'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 298-22', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '304605924', 'phone': '1661-7766', 'place_name': '카페더라이트 전기차충전소', 'place_url': 'http://place.map.kakao.com/304605924', 'road_address_name': '제주특별자치도 서귀포시 성산읍 한도로 269', 'x': '126.93592578379697', 'y': '33.46550615172082'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 170-13', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '25422660', 'phone': '1833-2377', 'place_name': '제주고가네식당 전기차충전소', 'place_url': 'http://place.map.kakao.com/25422660', 'road_address_name': '제주특별자치도 서귀포시 성산읍 성산중앙로19번길 14', 'x': '126.93130658351568', 'y': '33.46275286798296'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 170-13', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '805634505', 'phone': '1833-2377', 'place_name': '제주고가네식당 전기차충전소', 'place_url': 'http://place.map.kakao.com/805634505', 'road_address_name': '제주특별자치도 서귀포시 성산읍 성산중앙로19번길 14', 'x': '126.93130658351527', 'y': '33.46275286805541'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 169-16', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '1067605287', 'phone': '1522-2573', 'place_name': '다올-성산썬라이즈호텔 전기차충전소', 'place_url': 'http://place.map.kakao.com/1067605287', 'road_address_name': '제주특별자치도 서귀포시 성산읍 성산등용로17번길 35', 'x': '126.931026144691', 'y': '33.462348791243'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 399-10', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '1110671315', 'phone': '1670-2690', 'place_name': '해촌 전기차충전소', 'place_url': 'http://place.map.kakao.com/1110671315', 'road_address_name': '제주특별자치도 서귀포시 성산읍 일출로 220', 'x': '126.930006747115', 'y': '33.4592169288569'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 382-10', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '332335776', 'phone': '062-941-9360', 'place_name': '보말명가 전기차충전소', 'place_url': 'http://place.map.kakao.com/332335776', 'road_address_name': '제주특별자치도 서귀포시 성산읍 성산등용로 44', 'x': '126.930597704317', 'y': '33.4667898796298'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 382-6', 'category_grou ...
# 모든 데이터를 가져왔습니다!
# {'documents': [{'address_name': '제주특별자치도 서귀포시 성산읍 성산리 358-3', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '1189338887', 'phone': '1533-5421', 'place_name': '제주 온더스톤 게스트하우스(카페) 제주성산일출봉점 전기차충전소', 'place_url': 'http://place.map.kakao.com/1189338887', 'road_address_name': '제주특별자치도 서귀포시 성산읍 성산등용로 100-4', 'x': '126.93069512874', 'y': '33.4700826093008'}], 'meta': {'is_end': True, 'pageable_count': 16, 'same_name': {'keyword': '전기충전소', 'region': [], 'selected_region': '제주 서귀포시 성산일출봉'}, 'total_count': 16}}
# 모든 데이터를 가져왔습니다!
# {'documents': [{'address_name': '제주특별자치도 서귀포시 성산읍 성산리 358-3', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '1189338887', 'phone': '1533-5421', 'place_name': '제주 온더스톤 게스트하우스(카페) 제주성산일출봉점 전기차충전소', 'place_url': 'http://place.map.kakao.com/1189338887', 'road_address_name': '제주특별자치도 서귀포시 성산읍 성산등용로 100-4', 'x': '126.93069512874', 'y': '33.4700826093008'}], 'meta': {'is_end': True, 'pageable_count': 16, 'same_name': {'keyword': '전기충전소', 'region': [], 'selected_region': '제주 서귀포시 성산일출봉'}, 'total_count': 16}}
# 모든 데이터를 가져왔습니다!
# {'documents': [{'address_name': '제주특별자치도 서귀포시 성산읍 고성리 232', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '1179258933', 'phone': '1833-9131', 'place_name': '제주 성산 고등어쌈밥 김치찜 전기차충전소', 'place_url': 'http://place.map.kakao.com/1179258933', 'road_address_name': '제주특별자치도 서귀포시 성산읍 섭지코지로25번길 122-5', 'x': '126.92071866026838', 'y': '33.44949467862351'}, {'address_name': '제주특별자치도 서귀포시 성산읍 고성리 2747', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '702334016', 'phone': '1899-8852', 'place_name': '광치기해변공영주차장 전기차충전소', 'place_url': 'http://place.map.kakao.com/702334016', 'road_address_name': '', 'x': '126.92464263123713', 'y': '33.455251207092616'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 170-13', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '25422660', 'phone': '1833-2377', 'place_name': '제주고가네식당 전기차충전소', 'place_url': 'http://place.map.kakao.com/25422660', 'road_address_name': '제주특별자치도 서귀포시 성산읍 성산중앙로19번길 14', 'x': '126.93130658351568', 'y': '33.46275286798296'}, {'address_name': '제주특별자치도 서귀포시 성산읍 오조리 57-35', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '1494975870', 'phone': '1899-2100', 'place_name': '성산하수처리장 전기차충전소', 'place_url': 'http://place.map.kakao.com/1494975870', 'road_address_name': '제주특별자치도 서귀포시 성산읍 고성동서로 115', 'x': '126.91895562154767', 'y': '33.45205231152755'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 170-13', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '805634505', 'phone': '1833-2377', 'place_name': '제주고가네식당 전기차충전소', 'place_url': 'http://place.map.kakao.com/805634505', 'road_address_name': '제주특별자치도 서귀포시 성산읍 성산중앙로19번길 14', 'x': '126.93130658351527', 'y': '33.46275286805541'}, {'address_name': '제주특별자치도 서귀포시 성산읍 고성리 297-1', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '1517575373', 'phone': '1522-1782', 'place_name': '성산 플레이스 전기차충전소', 'place_url': 'http://place.map.kakao.com/1517575373', 'road_address_name': '제주특별자치도 서귀포시 성산읍 동류암로 20', 'x': '126.91837786491962', 'y': '33.44994216236302'}, {'address_name': '제주특별자치도 서귀포시 성산읍 고성리 372-1', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '686723060', 'phone': '', 'place_name': '성산스튜디오 전기차충전소', 'place_url': 'http://place.map.kakao.com/686723060', 'road_address_name': '제주특별자치도 서귀포시 성산읍 섭지코지로25번길 64', 'x': '126.91908523755353', 'y': '33.44451312003224'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 169-16', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '1067605287', 'phone': '1522-2573', 'place_name': '다올-성산썬라이즈호텔 전기차충전소', 'place_url': 'http://place.map.kakao.com/1067605287', 'road_address_name': '제주특별자치도 서귀포시 성산읍 성산등용로17번길 35', 'x': '126.931026144691', 'y': '33.462348791243'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 399-10', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '1110671315', 'phone': '1670-2690', 'place_name': '해촌 전기차충전소', 'place_url': 'http://place.map.kakao.com/1110671315', 'road_address_name': '제주특별자치도 서귀포시 성산읍 일출로 220', 'x': '126.930006747115', 'y': '33.4592169288569'}, {'address_name': '제주특별자치도 서귀포시 성산읍 고성리 235', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '1198391625', 'phone': '1533-5421', 'place_name': '제주 호랑호랑 펜션 전기차충전소', 'place_url': 'http://place.map.kakao.com/1198391625', 'road_address_name': '제주특별자치도 서귀포시 성산읍 일출로 86', 'x': '126.92154419435336', 'y': '33.45002895764521'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 141', 'category_group_code': '', 'c ...
# 61 개 중 45개 데이터밖에 가져오지 못했습니다!
# {'documents': [{'address_name': '제주특별자치도 서귀포시 성산읍 고성리 298-41', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '330194628', 'phone': '062-941-9360', 'place_name': '제주룩스호텔 전기차충전소', 'place_url': 'http://place.map.kakao.com/330194628', 'road_address_name': '제주특별자치도 서귀포시 성산읍 동류암로 38', 'x': '126.91630180613755', 'y': '33.44908785404104'}, {'address_name': '제주특별자치도 서귀포시 성산읍 오조리 152-1', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '701865181', 'phone': '1899-8852', 'place_name': '오조리종합복지회관 전기차충전소', 'place_url': 'http://place.map.kakao.com/701865181', 'road_address_name': '제주특별자치도 서귀포시 성산읍 오조로 77', 'x': '126.91522844104323', 'y': '33.46122731105204'}, {'address_name': '제주특별자치도 서귀포시 성산읍 고성리 329-1', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '771565762', 'phone': '1522-1782', 'place_name': '튤립제주에이엠씨 호텔 전기차충전소', 'place_url': 'http://place.map.kakao.com/771565762', 'road_address_name': '제주특별자치도 서귀포시 성산읍 일출로 31', 'x': '126.91621685822314', 'y': '33.4479490613063'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 114-3', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '2126955165', 'phone': '', 'place_name': '성산일출봉 전기차충전소', 'place_url': 'http://place.map.kakao.com/2126955165', 'road_address_name': '제주특별자치도 서귀포시 성산읍 일출로 284-6', 'x': '126.93554153441724', 'y': '33.46143067760281'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 177-3', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '1054258278', 'phone': '1588-5339', 'place_name': '휴안스테이호텔 전기차충전소', 'place_url': 'http://place.map.kakao.com/1054258278', 'road_address_name': '제주특별자치도 서귀포시 성산읍 성산중앙로40번길 4', 'x': '126.93367179272992', 'y': '33.46310037403955'}, {'address_name': '제주특별자치도 서귀포시 성산읍 고성리 336-2', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '591552122', 'phone': '1899-8852', 'place_name': '성산보건지소 전기차충전소', 'place_url': 'http://place.map.kakao.com/591552122', 'road_address_name': '제주특별자치도 서귀포시 성산읍 고성오조로 42', 'x': '126.91574820330197', 'y': '33.446554852060174'}, {'address_name': '제주특별자치도 서귀포시 성산읍 고성리 1216-1', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '383765005', 'phone': '1833-8017', 'place_name': '성산휴안1차 전기차충전소', 'place_url': 'http://place.map.kakao.com/383765005', 'road_address_name': '제주특별자치도 서귀포시 성산읍 일주동로 4193', 'x': '126.911924591997', 'y': '33.454195153597'}, {'address_name': '제주특별자치도 서귀포시 성산읍 오조리 741', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '157697403', 'phone': '1670-2690', 'place_name': '슬로우트립 게스트하우스 전기차충전소', 'place_url': 'http://place.map.kakao.com/157697403', 'road_address_name': '제주특별자치도 서귀포시 성산읍 오조로85번길 4', 'x': '126.91460749257702', 'y': '33.46151089195372'}, {'address_name': '제주특별자치도 서귀포시 성산읍 고성리 437-1', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '1055154526', 'phone': '1588-5339', 'place_name': '티라호텔 전기차충전소', 'place_url': 'http://place.map.kakao.com/1055154526', 'road_address_name': '제주특별자치도 서귀포시 성산읍 섭지코지로25번길 41', 'x': '126.918510572498', 'y': '33.4425968176465'}, {'address_name': '제주특별자치도 서귀포시 성산읍 고성리 1090-16', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '275674210', 'phone': '1522-1782', 'place_name': '성산아쿠아비치호텔 전기차충전소', 'place_url': 'http://place.map.kakao.com/275674210', 'road_address_name': '제주특별자치도 서귀포시 성산읍 일주동로 4258', 'x': '126.91199719559462', 'y': '33.44833743787008'}, {'address_name': '제주특별자치도 서귀포시 성산읍 오조리 990-1', 'category_group_code': ...
# 61 개 중 45개 데이터밖에 가져오지 못했습니다!
# {'documents': [{'address_name': '제주특별자치도 서귀포시 성산읍 고성리 1106-7', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '119303262', 'phone': '1522-1782', 'place_name': 'KT 성산포지사 전기차충전소', 'place_url': 'http://place.map.kakao.com/119303262', 'road_address_name': '제주특별자치도 서귀포시 성산읍 서성일로 1244-3', 'x': '126.91162559663067', 'y': '33.44675123873072'}, {'address_name': '제주특별자치도 서귀포시 성산읍 고성리 1142', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '366691641', 'phone': '1670-2690', 'place_name': '성산LH아파트 전기차충전소', 'place_url': 'http://place.map.kakao.com/366691641', 'road_address_name': '제주특별자치도 서귀포시 성산읍 고성동서로 33', 'x': '126.90982999483558', 'y': '33.45043122565768'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 293-1', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '1150578399', 'phone': '1533-5421', 'place_name': '제주 스타펜션민박 전기차충전소', 'place_url': 'http://place.map.kakao.com/1150578399', 'road_address_name': '제주특별자치도 서귀포시 성산읍 성산중앙로64번길 5-1', 'x': '126.93557249234316', 'y': '33.46465935757893'}, {'address_name': '제주특별자치도 서귀포시 성산읍 오조리 933', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '780696295', 'phone': '1899-2100', 'place_name': '동부소방서 전기차충전소', 'place_url': 'http://place.map.kakao.com/780696295', 'road_address_name': '제주특별자치도 서귀포시 성산읍 일주동로4120번길 7', 'x': '126.91002723629228', 'y': '33.46044375317747'}, {'address_name': '제주특별자치도 서귀포시 성산읍 고성리 448-1', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '571896330', 'phone': '1670-2690', 'place_name': '농업회사법인 백록 전기차충전소', 'place_url': 'http://place.map.kakao.com/571896330', 'road_address_name': '제주특별자치도 서귀포시 성산읍 섭지코지로25번길 12', 'x': '126.91997442915691', 'y': '33.44007776366862'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 298-22', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '304605924', 'phone': '1661-7766', 'place_name': '카페더라이트 전기차충전소', 'place_url': 'http://place.map.kakao.com/304605924', 'road_address_name': '제주특별자치도 서귀포시 성산읍 한도로 269', 'x': '126.93592578379697', 'y': '33.46550615172082'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 347-9', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '976033636', 'phone': '1661-9408', 'place_name': '성산항 공영주차장 전기차충전소', 'place_url': 'http://place.map.kakao.com/976033636', 'road_address_name': '제주특별자치도 서귀포시 성산읍 성산등용로 112-7', 'x': '126.932250859244', 'y': '33.4726791997205'}, {'address_name': '제주특별자치도 서귀포시 성산읍 오조리 577-1', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '1530973782', 'phone': '1833-8017', 'place_name': '오조로식당 전기차충전소', 'place_url': 'http://place.map.kakao.com/1530973782', 'road_address_name': '제주특별자치도 서귀포시 성산읍 오조로 131', 'x': '126.91302032671706', 'y': '33.465267696316374'}, {'address_name': '제주특별자치도 서귀포시 성산읍 고성리 1023-2', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '22484142', 'phone': '1899-8852', 'place_name': '성산읍사무소 전기차충전소', 'place_url': 'http://place.map.kakao.com/22484142', 'road_address_name': '제주특별자치도 서귀포시 성산읍 일주동로 4330', 'x': '126.91175581280673', 'y': '33.442423593554985'}, {'address_name': '제주특별자치도 서귀포시 성산읍 고성리 1448-1', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '210731697', 'phone': '1833-8017', 'place_name': '성산서부교회 전기차충전소', 'place_url': 'http://place.map.kakao.com/210731697', 'road_address_name': '제주특별자치도 서귀포시 성산읍 고성중앙로 52', 'x': '126.90866605079634', 'y': '33.44856674318751'}, {'address_name': '제주특별자치도 서귀포시 성산읍 고성리 1040-1', 'catego ...
# 61 개 중 45개 데이터밖에 가져오지 못했습니다!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bd67097cd7e0d1c459bda790bf31b119 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bd67097cd7e0d1c459bda790bf31b119&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bd67097cd7e0d1c459bda790bf31b119 = L.map(
#                 &quot;map_bd67097cd7e0d1c459bda790bf31b119&quot;,
#                 {
#                     center: [33.4935, 126.6266],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_86f7b805f6ac380dda854dfd7b4d9445 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_86f7b805f6ac380dda854dfd7b4d9445.addTo(map_bd67097cd7e0d1c459bda790bf31b119);
#
#
#             var tile_layer_951a0e6736b8ea4130aa39b7a66c65e1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_e858f566879810558910824347e753f8 = new L.Control.MiniMap(
#                 tile_layer_951a0e6736b8ea4130aa39b7a66c65e1,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomright&quot;, &quot;toggleDisplay&quot;: false, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_bd67097cd7e0d1c459bda790bf31b119.addControl(mini_map_e858f566879810558910824347e753f8);
#
#
#             var marker_c1388128218caf4f94f194f263884813 = L.marker(
#                 [33.46143067760281, 126.93554153441724],
#                 {}
#             ).addTo(map_bd67097cd7e0d1c459bda790bf31b119);
#
#
#         var popup_43fe822da6efeecd16c8c8d8e130cd9a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_81ebdc4b9ac165ae0decf6137bac0fe2 = $(`&lt;div id=&quot;html_81ebdc4b9ac165ae0decf6137bac0fe2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/2126955165&lt;/div&gt;`)[0];
#                 popup_43fe822da6efeecd16c8c8d8e130cd9a.setContent(html_81ebdc4b9ac165ae0decf6137bac0fe2);
#
#
#
#         marker_c1388128218caf4f94f194f263884813.bindPopup(popup_43fe822da6efeecd16c8c8d8e130cd9a)
#         ;
#
#
#
#
#             marker_c1388128218caf4f94f194f263884813.bindTooltip(
#                 `&lt;div&gt;
#                      성산일출봉 전기차충전소
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_147f11ec07f718a0fd11bebd1c28627b = L.marker(
#                 [33.461200809073716, 126.9339088143998],
#                 {}
#             ).addTo(map_bd67097cd7e0d1c459bda790bf31b119);
#
#
#         var popup_eb3fb160ecd929e4b4ce642d7c85b90b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_95d1c34fdec84afe66e979360c1ae47e = $(`&lt;div id=&quot;html_95d1c34fdec84afe66e979360c1ae47e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;http://place.map.kakao.com/359173519&lt;/div&gt;`)[0];
#                 popup_eb3fb160ecd929e4b4ce642d7c85b90b.setContent(html_95d1c34fdec84afe66e979360c1ae47e);
#
#
#
#         marker_147f11ec07f718a0fd11bebd1c28627b.bindPopup(popup_eb3fb160ecd929e4b4ce642d7c85b90b)
#         ;
#
#
#
#
#             marker_147f11ec07f718a0fd11bebd1c28627b.bindTooltip(
#                 `&lt;div&gt;
#                      돌하르방뚝배기식당 전기차충전소
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_904bdf2f18349fbd5e94adc004c08209 = L.marker(
#                 [33.46465935757893, 126.93557249234316],
#                 {}
#             ).addTo(map_bd67097cd7e0d1c459bda790bf31b119);
#
#
#         var popup_41e719d9c68182f8a5172c05ff22c930 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_beb07a30455c4da4ab9ec22da5e53d2d = $(`&lt;div id=&quot;html_beb07a30455c4da4ab9ec22da5e53d2d&quot; style=&quot;width: 100.0%; height: 100.0%;&

# %%
import requests 
url = 'https://dapi.kakao.com/v2/local/search/keyword.json' 
params = {'query': "성산일출봉 전기충전소",'page': 1} 
headers = {"Authorization": f"KakaoAK {KAKAO_API}"}
places = requests.get(url, params=params, headers=headers).json()['documents']
total = requests.get(url, params=params, headers=headers).json()['meta']['total_count'] 
if total > 45: 
    print(total,'개 중 45개 데이터밖에 가져오지 못했습니다!') 
else : 
    print('모든 데이터를 가져왔습니다!') 
    print(places)
# Out:
# 모든 데이터를 가져왔습니다!
# [{'address_name': '제주특별자치도 서귀포시 성산읍 성산리 114-3', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '2126955165', 'phone': '', 'place_name': '성산일출봉 전기차충전소', 'place_url': 'http://place.map.kakao.com/2126955165', 'road_address_name': '제주특별자치도 서귀포시 성산읍 일출로 284-6', 'x': '126.93554153441724', 'y': '33.46143067760281'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 141', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '359173519', 'phone': '062-941-9360', 'place_name': '돌하르방뚝배기식당 전기차충전소', 'place_url': 'http://place.map.kakao.com/359173519', 'road_address_name': '제주특별자치도 서귀포시 성산읍 일출로 264', 'x': '126.9339088143998', 'y': '33.461200809073716'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 293-1', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '1150578399', 'phone': '1533-5421', 'place_name': '제주 스타펜션민박 전기차충전소', 'place_url': 'http://place.map.kakao.com/1150578399', 'road_address_name': '제주특별자치도 서귀포시 성산읍 성산중앙로64번길 5-1', 'x': '126.93557249234316', 'y': '33.46465935757893'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 177-3', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '1054258278', 'phone': '1588-5339', 'place_name': '휴안스테이호텔 전기차충전소', 'place_url': 'http://place.map.kakao.com/1054258278', 'road_address_name': '제주특별자치도 서귀포시 성산읍 성산중앙로40번길 4', 'x': '126.93367179272992', 'y': '33.46310037403955'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 298-22', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '304605924', 'phone': '1661-7766', 'place_name': '카페더라이트 전기차충전소', 'place_url': 'http://place.map.kakao.com/304605924', 'road_address_name': '제주특별자치도 서귀포시 성산읍 한도로 269', 'x': '126.93592578379697', 'y': '33.46550615172082'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 170-13', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '25422660', 'phone': '1833-2377', 'place_name': '제주고가네식당 전기차충전소', 'place_url': 'http://place.map.kakao.com/25422660', 'road_address_name': '제주특별자치도 서귀포시 성산읍 성산중앙로19번길 14', 'x': '126.93130658351568', 'y': '33.46275286798296'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 170-13', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '805634505', 'phone': '1833-2377', 'place_name': '제주고가네식당 전기차충전소', 'place_url': 'http://place.map.kakao.com/805634505', 'road_address_name': '제주특별자치도 서귀포시 성산읍 성산중앙로19번길 14', 'x': '126.93130658351527', 'y': '33.46275286805541'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 169-16', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '1067605287', 'phone': '1522-2573', 'place_name': '다올-성산썬라이즈호텔 전기차충전소', 'place_url': 'http://place.map.kakao.com/1067605287', 'road_address_name': '제주특별자치도 서귀포시 성산읍 성산등용로17번길 35', 'x': '126.931026144691', 'y': '33.462348791243'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 399-10', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '1110671315', 'phone': '1670-2690', 'place_name': '해촌 전기차충전소', 'place_url': 'http://place.map.kakao.com/1110671315', 'road_address_name': '제주특별자치도 서귀포시 성산읍 일출로 220', 'x': '126.930006747115', 'y': '33.4592169288569'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 382-10', 'category_group_code': '', 'category_group_name': '', 'category_name': '교통,수송 > 자동차 > 전기자동차 충전소', 'distance': '', 'id': '332335776', 'phone': '062-941-9360', 'place_name': '보말명가 전기차충전소', 'place_url': 'http://place.map.kakao.com/332335776', 'road_address_name': '제주특별자치도 서귀포시 성산읍 성산등용로 44', 'x': '126.930597704317', 'y': '33.4667898796298'}, {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 382-6', 'category_group_code': '', ' ...
